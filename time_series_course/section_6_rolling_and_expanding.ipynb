# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./data/section_6/starbucks.csv", index_col="Date", parse_dates=True)

# %%
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df["Close"].plot.line(figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# rolling 7-day average

df.rolling(window=7).mean().head(10)
# Out:
#                 Close        Volume
# Date
# 2015-01-02        NaN           NaN
# 2015-01-05        NaN           NaN
# 2015-01-06        NaN           NaN
# 2015-01-07        NaN           NaN
# 2015-01-08        NaN           NaN
# 2015-01-09        NaN           NaN
# 2015-01-12  37.616786  1.238222e+07
# 2015-01-13  37.578786  1.297288e+07
# 2015-01-14  37.614786  1.264020e+07
# 2015-01-15  37.638114  1.270624e+07

# %%
# rolling 45-day average

df["Close"].plot.line(figsize=(12, 5))

df.rolling(window=45).mean()["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df["Close: 45 Day Mean"] = df["Close"].rolling(window=45).mean()

# %%
df[["Close", "Close: 45 Day Mean"]].plot(figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Pandas Expanding
#
# A common alternative to rolling statistics is to use an expanding window, which yields the value of the statistic with all the data available up to that point in time.
#
# In this case, the data point at 2015-07 is the average value for all the rows up to that point. In other words, it is the mean value between 2015-01 and 2015-07.
#
# Of note, the very last data point is essentially the average value for all the rows in a dataset.

# %%
df["Close"].expanding(min_periods=1).mean().plot(figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='Date'>
