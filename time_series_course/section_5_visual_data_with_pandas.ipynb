# %%
import pandas as pd

# %matplotlib inline

# %%
df = pd.read_csv("./data/section_5/data.csv", index_col=0)

# %%
df.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv("./data/section_5/data2.csv")

# %%
df2
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y
# 5  0.286043  0.593465  0.907307  0.637898  x
# 6  0.430436  0.166230  0.469383  0.497701  z
# 7  0.312296  0.502823  0.806609  0.850519  z
# 8  0.187765  0.997075  0.895955  0.530390  x
# 9  0.908162  0.232726  0.414138  0.432007  y

# %%
df["A"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["A"].plot.hist(grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["A"].plot.hist(bins=20, edgecolor="k").autoscale(enable=True, axis="both", tight=True)

# %%
df2.head()
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df2.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df2.plot.line(y=["a", "b", "c"], figsize=(10, 4), lw=3)
# Out:
# <AxesSubplot:>

# %%
df2.plot.area(alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x="A", y="B")
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df.plot.scatter(x="A", y="B", c="D", cmap="coolwarm")
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df.plot.scatter(x="A", y="B", s=df["C"] * 100, alpha=0.2)
# Out:
# C:\Users\steve\AppData\Roaming\Python\Python310\site-packages\matplotlib\collections.py:982: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y
# 5  0.286043  0.593465  0.907307  0.637898  x
# 6  0.430436  0.166230  0.469383  0.497701  z
# 7  0.312296  0.502823  0.806609  0.850519  z
# 8  0.187765  0.997075  0.895955  0.530390  x
# 9  0.908162  0.232726  0.414138  0.432007  y

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
# Kernel Density Estimation

df2.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=["A", "B"])

# %%
df
# Out:
#             A         B
# 0   -1.155091 -1.414701
# 1    0.241414  1.468376
# 2   -1.952588 -0.531618
# 3    2.372743 -2.135911
# 4    0.050379  1.014147
# ..        ...       ...
# 995 -0.384582 -0.664758
# 996 -1.163239 -1.552697
# 997 -1.266399 -0.045351
# 998 -1.062775 -0.470361
# 999 -0.765817 -0.965129
#
# [1000 rows x 2 columns]

# %%
df.plot.scatter(x="A", y="B")
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df.plot.hexbin(x="A", y="B", gridsize=15, cmap="coolwarm")
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>
